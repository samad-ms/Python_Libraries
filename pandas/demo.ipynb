# %% [markdown]
# # Pandas - part1 indtroduction
# Pandas is a Python library for data manipulation and analysis, offering powerful data structures like DataFrames and Series to organize and work with structured data efficiently. It facilitates tasks such as data cleaning, transformation, aggregation, and visualization, making it a fundamental tool in data science and analysis.

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Program Files\\Anaconda\\Lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# ### reading data from csv - Stack Overflow Annual Developer Survey

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df=pd.read_csv('data/survey_results_schema.csv')

# %% [markdown]
# ### Dataset Information

# %%
# df.head()
# df.tail()
# df.info()
# df.describe()
# df.shape
# df.columns

# df.duplicated()
# df.duplicated().sum()
# df.duplicated(subset=['MainBranch']).sum()

# %% [markdown]
# ##### by default it only shows 20 columns but our data has 85 column , how to show all column

# %%
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 84)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %% [markdown]
# # part 2-DataFrame and series-continuation

# %%
# df.head()
schema_df.head(1)
# Out:
#      qid qname                                           question force_resp  \
# 0  QID16    S0  <div><span style="font-size:19px;"><strong>Hel...      False
#
#   type selector
# 0   DB       TB

# %%
# schema_df.shape
# df.shape

# %%
# df.columns
df['SOAccount']
# Out:
# 0        NaN
# 1        Yes
# 2        Yes
# 3        Yes
# 4         No
#         ...
# 89179    Yes
# 89180    Yes
# 89181    NaN
# 89182     No
# 89183    Yes
# Name: SOAccount, Length: 89184, dtype: object

# %%
df['SOAccount'].value_counts()
# Out:
# Yes                        66282
# No                         14618
# Not sure/can't remember     6952
# Name: SOAccount, dtype: int64

# %%
#slicing needed rows and columns
df.loc[0:2,'Age':'CodingActivities']
# Out:
#                Age           Employment                            RemoteWork  \
# 0  18-24 years old                  NaN                                   NaN
# 1  25-34 years old  Employed, full-time                                Remote
# 2  45-54 years old  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...

# %% [markdown]
# # part 3-indexing

# %%
import pandas as pd
#we remove default indexing which unwanted , and set as index
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
df.head(1)
# Out:
#                Q120     MainBranch              Age Employment RemoteWork  \
# ResponseId
# 1           I agree  None of these  18-24 years old        NaN        NaN
#
#            CodingActivities EdLevel LearnCode LearnCodeOnline  \
# ResponseId
# 1                       NaN     NaN       NaN             NaN
#
#            LearnCodeCoursesCert YearsCode YearsCodePro DevType OrgSize  \
# ResponseId
# 1                           NaN       NaN          NaN     NaN     NaN
#
#            PurchaseInfluence TechList BuyNewTool Country Currency  CompTotal  \
# ResponseId
# 1                        NaN      NaN        NaN     NaN      NaN        NaN
#
#            LanguageHaveWorkedWith LanguageWantToWorkWith  \
# ResponseId
# 1                             NaN                    NaN
#
#            DatabaseHaveWorkedWith DatabaseWantToWorkWith  \
# ResponseId
# 1                             NaN                    NaN
#
#            PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ...

# %%
schema_df=pd.read_csv('data/survey_results_schema.csv',index_col='qname')
schema_df.head(1)
# Out:
#          qid                                           question force_resp  \
# qname
# S0     QID16  <div><span style="font-size:19px;"><strong>Hel...      False
#
#       type selector
# qname
# S0      DB       TB

# %%
schema_df.index
# Out:
# Index(['S0', 'MetaInfo', 'Q310', 'Q120', 'S1', 'MainBranch', 'Age',
#        'Employment', 'RemoteWork', 'CodingActivities', 'S2', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'TechList',
#        'BuyNewTool', 'Country', 'Currency', 'CompTotal', 'S3', 'Language',
#        'Database', 'Platform', 'Webframe', 'MiscTech', 'ToolsTech',
#        'NEWCollabTools', 'OpSys', 'OfficeStackAsync', 'OfficeStackSync',
#        'AISearch', 'AIDev', 'S4', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOComm', 'S5', 'SOAI', 'AISelect', 'AISent', 'AIAcc',
#        'AIBen', 'AITool', 'AINext', 'AIOpen', 'S6', 'TBranch', 'ICorPM',
#        'WorkExp', 'Knowledge', 'Frequency', 'TimeSearching', 'TimeAnswering',
#        'ProfessionalTech', 'Industry', 'SOTeamsUsage', 'S7', 'SurveyLength',
#        'SurveyEase', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3',
# ...

# %%
schema_df.loc['SOAccount']
schema_df.loc['SOAccount','question']
# Out:
# 'Do you have a Stack Overflow account?'

# %%
schema_df.iloc[0]
# Out:
# qid                                                       QID16
# question      <div><span style="font-size:19px;"><strong>Hel...
# force_resp                                                False
# type                                                         DB
# selector                                                     TB
# Name: S0, dtype: object

# %%
schema_df.sort_index(inplace=True)
schema_df.head(3)
# Out:
#           qid                                           question force_resp  \
# qname
# AIAcc  QID324  For the AI tools you use as part of your devel...      False
# AIBen  QID316  How much do you trust the accuracy of the outp...      False
# AIDev  QID328  Which <b>AI-powered developer tools</b> did yo...      False
#
#          type selector
# qname
# AIAcc      MC     MAVR
# AIBen      MC     SAVR
# AIDev  Matrix   Likert

# %%
# part 4-indexing
